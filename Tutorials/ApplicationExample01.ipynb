# %% [markdown]
# End to end mesh gen:
# ----------------------------------
# ```
# Please use OCSMesh > version 2.1
#
# Needs to prepare the following folders:
#     path/
#     |-- inputs/
#     |   |-- hgrid.gr3
#     |   |-- total_river_polys.shp
#     |   |-- regimes.shp
#     |   |-- dems/
#     |       |-- gebco_file.tif
#     |-- outputs/
# ```
# - **path:** your directory
#
# - **hgrid.gr3:** STOFS3D mesh, used for defining the model domain.
#     Please download from: https://ccrm.vims.edu/yinglong/feiye/Public/OCSMesh/
#
# - **total_river_polys.shp:** RiverMapper polygons, used to create the river mesh.
#     Please download from: https://ccrm.vims.edu/yinglong/feiye/Public/OCSMesh/
#     For details on how to create this file, please refer to: https://github.com/schism-dev/RiverMeshTools
#
# - **regimes.shp:** Output from the separation of the ocean regimes (see tutorial on regime separation).
#
# - **gebco_file.tif:** should be placed inside dems/, should cover the entire model domain.
#     Please download it from: https://download.gebco.net/
#     Using the coordinates: -98.5 -51.0, 3, 53
#
# - **outputs/:** where outputs (final mesh) will be saved.

# %%
import os
import time
from copy import deepcopy

import numpy as np
import pandas as pd
import geopandas as gpd

from shapely.geometry import (
                              Polygon, MultiPolygon, mapping
                             )
from shapely import intersection,difference

import ocsmesh

# %%
path = r"/Your/Path/Here/"

# %% [markdown]
# ## Model Domain:

# %% [markdown]
# This step is only needed if you do not have a shapefile of the model domain and wants it to match that of STOFS

# %%
STOFS_mesh = ocsmesh.Mesh.open(path+"inputs/hgrid.gr3", crs=4326)

poly_STOFS = ocsmesh.utils.get_mesh_polygons(STOFS_mesh.meshdata)

gdf = gpd.GeoDataFrame(geometry = gpd.GeoSeries(poly_STOFS),crs=4326).dissolve().explode()
gdf.to_file(path+"outputs/fp_domain.shp")

# %% [markdown]
# ## River Mesh:

# %% [markdown]
# Triangulates the RiverMapper polygons and clips it for the area of interest (model domain)

# %%
print("Begin River Mesh Gen")
start_time = time.time()

rm_poly = gpd.read_file(path+"inputs/total_river_polys.shp")
river_tr = ocsmesh.ops.river_mesh.triangulate_rivermapper_poly(rm_poly)
river_tr = ocsmesh.utils.clip_mesh_by_shape(river_tr, gdf.union_all(), adjacent_layers=10)
ocsmesh.Mesh(river_tr).write(path+"outputs/river_tr.2dm", format='2dm', overwrite=True)
del rm_poly, river_tr

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for RiverMesh: {elapsed_time} seconds")

# %% [markdown]
# ## Background Mesh (Floodplain + Ocean):

# %% [markdown]
# Floodplain and non-eddy parts of the mesh are highly customizible. Please see the OCSMesh manual: https://repository.library.noaa.gov/view/noaa/33879

# %%
print("Begin Background Mesh Gen")
start_time = time.time()

regimes = gpd.read_file(path+"inputs/regimes.shp")

dem_paths = [f"{path}inputs/dems/{dem}" for dem in os.listdir(path+"inputs/dems/")]
geom_rast_list = [ocsmesh.Raster(f) for f in dem_paths if f[-4:] == '.tif']
hfun_rast_list = [ocsmesh.Raster(f) for f in dem_paths if f[-4:] == '.tif']
safe_crs = [hfun_rast_list][0].crs
#Mesh gen:
geom = ocsmesh.Geom(
    geom_rast_list,
    base_shape=gdf.union_all(),
    crs=safe_crs
    # zmax=10
    )
hfun = ocsmesh.Hfun(
    hfun_rast_list,
    base_shape=gdf.union_all(),
    base_shape_crs=safe_crs,
    hmin=1000, hmax=6500,
    method='fast')

## Load the different ocean regimes:
ol_fixed = gpd.GeoDataFrame(geometry=gpd.GeoSeries(regimes.loc[0,'geometry']),crs=regimes.crs)
ne_fixed = gpd.GeoDataFrame(geometry=gpd.GeoSeries(regimes.loc[1,'geometry']),crs=regimes.crs)
tz_fixed = gpd.GeoDataFrame(geometry=gpd.GeoSeries(regimes.loc[2,'geometry']),crs=regimes.crs)
er_fixed = gpd.GeoDataFrame(geometry=gpd.GeoSeries(regimes.loc[3,'geometry']),crs=regimes.crs)
ol_clip = gpd.clip(ol_fixed,gdf.union_all(), keep_geom_type=False)
ne_clip = gpd.clip(ne_fixed,gdf.union_all(), keep_geom_type=False)
tz_clip = gpd.clip(tz_fixed,gdf.union_all(), keep_geom_type=False)
er_clip = gpd.clip(er_fixed,gdf.union_all(), keep_geom_type=False)

## Here we will keep the hfun customization simple:
## (overland at 1000m, and the rest at 6500m, with a smooth transition between the floodplain and the ocean)
hfun.add_patch(ol_clip.union_all(), target_size=1000, expansion_rate=1/17500)
hfun.add_patch(ne_clip.union_all(), target_size=6500)
hfun.add_region_constraint(value = 6500, shape=er_clip.union_all(), crs=safe_crs, value_type='min', rate = 1/5000)
hfun.add_region_constraint(value = 6500, shape=tz_clip.union_all(), crs=safe_crs, value_type='min',)

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for Background Mesh: {elapsed_time} seconds")

# %% [markdown]
# Mesh driver

# %%
print("Begin Mesh Gen, this might take a few hors...")
start_time = time.time()

driver = ocsmesh.MeshDriver(geom, hfun, engine_name='gmsh', bnd_representation='exact')
driver = driver.run()
driver.write(path+"outputs/fp_oc.2dm", format="2dm", overwrite=True)

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for Meshing: {elapsed_time} seconds")

# %% [markdown]
# ## Merging Meshes:

# %% [markdown]
# Merging the Background mesh (Floodplain+Ocean) and the river mesh.

# %%
print("Begin River Merge into the Floodplain+Ocean")
start_time = time.time()

fp_r_oc = ocsmesh.ops.combine_mesh.merge_overlapping_meshes([driver,river_tr], min_int_ang=25, adjacent_layers = 2)
fp_r_oc = ocsmesh.utils.order_mesh(fp_r_oc)
ocsmesh.Mesh(fp_r_oc).write(path+"outputs/fp_oc_rv.2dm", format='2dm', overwrite=True)
    
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for Floodplain_Ocean+River Mesh: {elapsed_time} seconds")
